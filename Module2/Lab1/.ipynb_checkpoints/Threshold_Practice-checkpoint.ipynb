# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

img = cv2.imread("../Images/Zebra.jpg")

h = 20
hColor = 20

templateWindowSize = 7
searchWindowSize = 21
'''
img = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)

blur = cv2.fastNlMeansDenoisingColored(img, None, h, hColor, templateWindowSize, searchWindowSize)
'''


blur = cv2.fastNlMeansDenoisingColored(img, None, h, hColor, templateWindowSize, searchWindowSize)

plt.imshow(cv2.cvtColor(blur, cv2.COLOR_BGR2RGB))

# %%
elKernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (13,13))

gradient = cv2.morphologyEx(blur, cv2.MORPH_GRADIENT, elKernel)

plt.imshow(gradient, cv2.BGR2RGB)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-074d16abe321> in <module>
#       3 gradient = cv2.morphologyEx(blur, cv2.MORPH_GRADIENT, elKernel)
#       4
# ----> 5 plt.imshow(gradient, cv2.BGR2RGB)
#
# AttributeError: module 'cv2.cv2' has no attribute 'BGR2RGB'
